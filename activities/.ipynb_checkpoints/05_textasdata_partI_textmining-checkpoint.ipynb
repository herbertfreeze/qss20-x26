# %% [markdown]
# # Imports

# %%
## load packages 
import pandas as pd
import re
import numpy as np

## nltk imports
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize

## uncomment and download if this is your first 
## time running 
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

## sentiment analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

## specify to print all output in a call
## and not just first
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Out:
#   Cell In[7], line 1
#     python -m spacy download en_core_web_sm
#               ^
# SyntaxError: invalid syntax

# %%
## spacy --- if you get an error at the load step
## need to download en_core_web_sm (google)
import spacy
sp = spacy.load('en_core_web_sm')
import en_core_web_sm
nlp = en_core_web_sm.load()

# %% [markdown]
# # Load data

# %%
## if working from within the repo, can use this relative path
path_todata = "../public_data/airbnb_text.csv"

## load data
ab = pd.read_csv(path_todata)
ab.head()
ab.info()
# Out:
#      id                                              name  \
# 0  2539                Clean & quiet apt home by the park
# 1  2595                             Skylit Midtown Castle
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !
# 3  3831                   Cozy Entire Floor of Brownstone
# 4  5022  Entire Apt: Spacious Studio/Loft by central park
#
#                                          name_upper neighbourhood_group  price
# 0                CLEAN & QUIET APT HOME BY THE PARK            Brooklyn    149
# 1                             SKYLIT MIDTOWN CASTLE           Manhattan    225
# 2               THE VILLAGE OF HARLEM....NEW YORK !           Manhattan    150
# 3                   COZY ENTIRE FLOOR OF BROWNSTONE            Brooklyn     89
# 4  ENTIRE APT: SPACIOUS STUDIO/LOFT BY CENTRAL PARK           Manhattan     80
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   48895 non-null  int64
#  1   name                 48879 non-null  object
#  2   name_upper           48879 non-null  object
#  3   neighbourhood_group  48895 non-null  object
#  4   price                48895 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# # Text mining

# %% [markdown]
# ## Manual approach 1: look for a single word

# %%
## using the `name_upper` var, look at where reviews mention cozy
ab['is_cozy'] = ab.name_upper.str.contains("COZY")

## find the mean price by neighborhood and whether cozy
mp = ab.groupby(['is_cozy', 'neighbourhood_group'])['price'].mean().reset_index()

## reshape to wide format so that each borough is row
## and one col is the mean price for listings that describe
## the place as cozy; other col is mean price for listings
## without that word
mp_wide = pd.pivot_table(mp, index = ['neighbourhood_group'],
                        columns = ['is_cozy'])

mp_wide.columns = ['no_mention_cozy', 'mention_cozy']

mp_wide
# Out:
#                      no_mention_cozy  mention_cozy
# neighbourhood_group
# Bronx                      89.231088     73.768000
# Brooklyn                  128.175441     91.155458
# Manhattan                 204.109775    129.647171
# Queens                    102.596682     80.344388
# Staten Island             120.650307     74.319149

# %% [markdown]
# ## Manual approach 2: score based on dictionary of words

# %%
## construct dictionary
space_indicators = {'small': ['COZY', 'COMFY', 'LITTLE', 'SMALL'],
                   'large': ['SPACIOUS', 'LARGE', 'HUGE', 'GIANT']}


## for each listing, find the number of occurrences
## of words in each key

### first, let's test with one listing
practice_listing = "NICE AND COZY LITTLE APT AVAILABLE"

### splitting that string at space and looking at overlap with each key
### first, look at overlap with the list containing words for small
words_overlap_small = [word 
                    for word in practice_listing.split(" ") if 
                      word in space_indicators['small']]
words_overlap_small
# Out:
# ['COZY', 'LITTLE']

# %%
### then, look at overlap with the list containing words for large
words_overlap_large = [word for word in practice_listing.split(" ") if 
                      word in space_indicators['large']]
words_overlap_large

### could then take length as a fraction of all words
len(words_overlap_small)/len(practice_listing.split(" "))
len(words_overlap_large)/len(practice_listing.split(" "))
# Out:
# []
# 0.3333333333333333
# 0.0

# %% [markdown]
# ## Part of speech tagging

# %%
## specify example
example_for_tag = "This is a chill apt next to the subway in LES Chinatown"
example_for_tag
# Out:
# 'This is a chill apt next to the subway in LES Chinatown'

# %%
## try part of speech tagging using nltk
tokens = word_tokenize(example_for_tag) # Generate list of tokens
tokens_pos = pos_tag(tokens) # generate part of speech tags for those tokens
 
## returns a list of tuples
## first element in tuple is a word
## second element in tuple is the part of speech
#for one_tok in tokens_pos:
 #   print(one_tok)
tokens_pos
# Out:
# [('This', 'DT'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('chill', 'NN'),
#  ('apt', 'JJ'),
#  ('next', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('subway', 'NN'),
#  ('in', 'IN'),
#  ('LES', 'NNP'),
#  ('Chinatown', 'NNP')]

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/cooper/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
## use list iteration to extract proper nouns (NNP)
## i'm first checking if the second element in the tuple
## is equal to NNP
## if so, i'm returning the first element in the tuple (the 
## actual word)
all_prop_noun = [one_tok[0] for one_tok in tokens_pos 
                if one_tok[1] == "NNP"]
all_prop_noun

all_adj_noun = [one_tok[0] for one_tok in tokens_pos 
                if one_tok[1] == "JJ" or 
               one_tok[1] == "NN"]
all_adj_noun
# Out:
# ['LES', 'Chinatown']
# ['chill', 'apt', 'next', 'subway']

# %% [markdown]
# ## Named Entity Recognition

# %%
## modified from a real tweet

## tweet
d_tweet = """We’ll be hosting on-campus COVID-19 booster clinics 
at Dartmouth College in New Hampshire from 9 a.m. to 6 p.m. on
Monday, Jan. 10, and Tuesday, Jan. 11, at
Alumni Hall in the Hopkins Center. For information on how to
register and additional winter updates, head to
"""

# %%
spacy_dtweet = nlp(d_tweet)
print(type(spacy_dtweet))
# Out:
# <class 'spacy.tokens.doc.Doc'>

# %%
## try a couple variations
for one_tok in spacy_dtweet.ents:
    print("Entity: " + one_tok.text + "; NER tag: " + one_tok.label_)
# Out:
# Entity: COVID-19; NER tag: ORG
# Entity: Dartmouth College; NER tag: ORG
# Entity: New Hampshire; NER tag: GPE
# Entity: 9 a.m. to 6 p.m.; NER tag: TIME
# Entity: Monday, Jan. 10; NER tag: DATE
# Entity: Tuesday, Jan. 11; NER tag: DATE
# Entity: Alumni Hall; NER tag: FAC
# Entity: the Hopkins Center; NER tag: ORG
# Entity: winter; NER tag: DATE

# %% [markdown]
# ### Challenge 1
#
# Play around with different variations of the Dartmouth tweet and look at the results. For instance, try the following:
#
# - What happens if you abbreviate New Hampshire to NH?
# - What happens if you add the word Pfizer before COVID-19?
# - What entities seem misclassified?

# %%
d_tweet2 = """We’ll be hosting on-campus Pfizer COVID-19 booster clinics 
at Dartmouth College in NH from 9 a.m. to 6 p.m. on
Monday, Jan. 10, and Tuesday, Jan. 11, at
Alumni Hall in the Hopkins Center. For information on how to
register and additional winter updates, head to
"""

# %%
spacy_dtweet2 = nlp(d_tweet2)
print(type(spacy_dtweet2))
# Out:
# <class 'spacy.tokens.doc.Doc'>

# %%
for one_tok in spacy_dtweet2.ents:
    print("Entity: " + one_tok.text + "; NER tag: " + one_tok.label_)
# Out:
# Entity: Dartmouth College; NER tag: ORG
# Entity: NH; NER tag: ORG
# Entity: 9 a.m. to 6 p.m.; NER tag: TIME
# Entity: Monday, Jan. 10; NER tag: DATE
# Entity: Tuesday, Jan. 11; NER tag: DATE
# Entity: Alumni Hall; NER tag: FAC
# Entity: the Hopkins Center; NER tag: ORG
# Entity: winter; NER tag: DATE

# %% [markdown]
# ### Challenge 2
#
# How do we generalize from doing Named Entity Recognition one just one string to doing NER on a whole column that contains strings? By defining and executing a **function**, of course!
#
# Using the following sample of strings from airbnb listing names, define a function that takes in one airbnb string and does the following:
#
# - iterates over entities in that string (list comprehension would work well for this)
# - checks if each label indicates a place
# - returns the text of each original place/entity
#
# Then execute the function on the example strings through iteration (again, list comprehension works well here).

# %%
## for runtime purposes, take a sample of the airbnb listing names
ab_name_examples = ab.name[10:15]
ab_name_examples
# Out:
# 10                    Beautiful 1br on Upper West Side
# 11                     Central Manhattan/near Broadway
# 12      Lovely Room 1, Garden, Best Area, Legal rental
# 13    Wonderful Guest Bedroom in Manhattan for SINGLES
# 14                       West Village Nest - Superhost
# Name: name, dtype: object

# %%
def airbnb(r):
    words = nlp(r)
    for i in words.ents:
        print("Entity: " + i.text + "; NER tag: " + i.label_)




ab.name.apply(airbnb)
# Out:
# Entity: Clean & quiet; NER tag: ORG
# Entity: HARLEM; NER tag: ORG
# Entity: NEW YORK; NER tag: GPE
# Entity: Cozy Entire Floor of Brownstone; NER tag: PERSON
# Entity: Cozy 1 BR Apartment In Midtown East; NER tag: PERSON
# Entity: Cozy Clean Guest Room - Family Apt; NER tag: ORG
# Entity: Cute & Cozy Lower East Side 1; NER tag: ORG
# Entity: 1br; NER tag: CARDINAL
# Entity: Central Manhattan; NER tag: LOC
# Entity: Broadway; NER tag: FAC
# Entity: Wonderful Guest Bedroom; NER tag: PERSON
# Entity: Manhattan; NER tag: GPE
# Entity: West Village Nest - Superhost; NER tag: GPE
# Entity: Only 2; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: Chelsea; NER tag: ORG
# Entity: Backyard; NER tag: PERSON
# Entity: Spacious Brooklyn Loft; NER tag: PERSON
# Entity: CBG; NER tag: ORG
# Entity: HelpsHaiti; NER tag: ORG
# Entity: 4; NER tag: CARDINAL
# Entity: 2; NER tag: MONEY
# Entity: SIRENES1,bohemian; NER tag: NORP
# Entity: Sunny Bedroom Across Prospect; NER tag: PERSON
# Entity: Magnifique Suite; NER tag: PERSON
# Entity: N de Manhattan - vue; NER tag: ORG
# Entity: Midtown Pied-; NER tag: PERSON
# Entity: SPACIOUS; NER tag: ORG
# Entity: LOVELY; NER tag: ORG
# Entity: Modern 1 BR / NYC / EAST VILLAGE; NER tag: PRODUCT
# Entity: 1; NER tag: CARDINAL
# Entity: Loft; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: Legal; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Sunny Park Slope; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: 1bdr; NER tag: CARDINAL
# Entity: HARLEM; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Suite; NER tag: PERSON
# Entity: Landmark Block; NER tag: ORG
# Entity: Charming Brownstone 3 - Near; NER tag: PERSON
# Entity: Fort Greene; NER tag: GPE
# Entity: 1350; NER tag: MONEY
# Entity: monthly; NER tag: DATE
# Entity: Cozy 1BD; NER tag: PERSON
# Entity: Central Park West; NER tag: LOC
# Entity: New York City; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Great Location; NER tag: ORG
# Entity: Manhattan; NER tag: GPE
# Entity: Sunny & Spacious Chelsea Apartment; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: 4; NER tag: CARDINAL
# Entity: Deck Clinton Hill Best Area; NER tag: PERSON
# Entity: Hells Kitchen; NER tag: GPE
# Entity: 2B; NER tag: CARDINAL
# Entity: Park Slope; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: Six; NER tag: CARDINAL
# Entity: HARLEM; NER tag: ORG
# Entity: NEW YORK; NER tag: GPE
# Entity: HOUSE; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: One; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: Fort Greene Retreat; NER tag: ORG
# Entity: Cozy 2 BR; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: Upper West NYC; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Bedroom - Large & Sunny; NER tag: ORG
# Entity: Lower East Side; NER tag: LOC
# Entity: 2; NER tag: CARDINAL
# Entity: Williamsburg Apt - Bedford L; NER tag: PERSON
# Entity: Cozy Bedroom; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: 3; NER tag: CARDINAL
# Entity: BR; NER tag: ORG
# Entity: Sunny; NER tag: ORG
# Entity: Landmark Home 1; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: 1; NER tag: CARDINAL
# Entity: GR8 WBurg; NER tag: PERSON
# Entity: Artist Home; NER tag: ORG
# Entity: Central Park; NER tag: LOC
# Entity: Manhattan; NER tag: GPE
# Entity: New York; NER tag: GPE
# Entity: 4; NER tag: CARDINAL
# Entity: The Stuydio Modern; NER tag: ORG
# Entity: loft bed -; NER tag: PERSON
# Entity: House; NER tag: ORG
# Entity: Henry; NER tag: GPE
# Entity: 3rd; NER tag: ORDINAL
# Entity: Monkey Retreat; NER tag: PERSON
# Entity: Manhattan; NER tag: GPE
# Entity: 2000; NER tag: DATE
# Entity: 2bath; NER tag: CARDINAL
# Entity: West Village; NER tag: GPE
# Entity: Williamsburg; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Groups; NER tag: ORG
# Entity: August; NER tag: DATE
# Entity: 1,800 sq foot; NER tag: QUANTITY
# Entity: Sunny 2-story; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Times Square; NER tag: FAC
# Entity: Cozy; NER tag: GPE
# Entity: Landmark Home 1 Block; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: Park Slope; NER tag: ORG
# Entity: Green Guest House; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: East Village; NER tag: GPE
# Entity: NYC; NER tag: ORG
# Entity: Manhattan; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Williamsburg; NER tag: GPE
# Entity: 1 BR; NER tag: QUANTITY
# Entity: East Village; NER tag: GPE
# Entity: Eveland Private Bed & Living Room w/ Own; NER tag: ORG
# Entity: Hill Rest Stop; NER tag: PERSON
# Entity: 3; NER tag: CARDINAL
# Entity: Story Town House; NER tag: ORG
# Entity: Park Slope; NER tag: ORG
# Entity: Central park; NER tag: LOC
# Entity: East Village Sanctuary; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: 3; NER tag: CARDINAL
# Entity: Q Trn; NER tag: PERSON
# Entity: the Upper East Sid; NER tag: LOC
# Entity: Secluded; NER tag: PERSON
# Entity: ACCOMMODATIONS GALORE; NER tag: ORG
# Entity: 1; NER tag: MONEY
# Entity: Sunny Room; NER tag: PERSON
# Entity: Stylish & Sleek Apartment Near SoHo; NER tag: ORG
# Entity: NYC; NER tag: ORG
# Entity: Unique & Charming; NER tag: ORG
# Entity: 1br; NER tag: ORDINAL
# Entity: LES; NER tag: ORG
# Entity: East Flatbush; NER tag: GPE
# Entity: FLAT MACDONOUGH; NER tag: ORG
# Entity: Modern Greenpoint; NER tag: ORG
# Entity: Brooklyn Apt; NER tag: PERSON
# Entity: 1; NER tag: CARDINAL
# Entity: FLAT MACDONOUGH GARDEN; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: NYC; NER tag: ORG
# Entity: Cozy BR; NER tag: PERSON
# Entity: Sunny Room; NER tag: PERSON
# Entity: Sun Filled; NER tag: ORG
# Entity: Historic Prospect Heights; NER tag: FAC
# Entity: Classic Artist; NER tag: PRODUCT
# Entity: Loft Williamsburg; NER tag: PERSON
# Entity: Private Bdrm/Bathrm; NER tag: ORG
# Entity: Sunny; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: W. Village; NER tag: GPE
# Entity: Williamsburg; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: BDR; NER tag: ORG
# Entity: Luxury Brownstone; NER tag: PERSON
# Entity: Boerum Hill; NER tag: GPE
# Entity: CENTRAL PARK; NER tag: LOC
# Entity: Indie-Chic Share; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Private, Large & Sunny; NER tag: ORG
# Entity: 1BR w/W&D; NER tag: MONEY
# Entity: Condo; NER tag: PRODUCT
# Entity: DUBMO; NER tag: ORG
# Entity: Charming & Cozy; NER tag: ORG
# Entity: 6; NER tag: CARDINAL
# Entity: max; NER tag: PERSON
# Entity: Manhattan; NER tag: GPE
# Entity: House; NER tag: ORG
# Entity: Henry; NER tag: PERSON
# Entity: 2nd; NER tag: ORDINAL
# Entity: New York; NER tag: GPE
# Entity: Brklyn; NER tag: PERSON
# Entity: Loft; NER tag: PERSON
# Entity: West Inn 2 - East Village; NER tag: PERSON
# Entity: Luxury Loft; NER tag: PERSON
# Entity: Lovely West Village Studio; NER tag: GPE
# Entity: ACCOMMODATIONS; NER tag: ORG
# Entity: 1-5; NER tag: CARDINAL
# Entity: Greenwich Village Stylish Apartment; NER tag: ORG
# Entity: Cozy Harlem Apartment; NER tag: PERSON
# Entity: Fort Greene; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Queens Brownstone; NER tag: ORG
# Entity: Park Slope; NER tag: ORG
# Entity: 15; NER tag: CARDINAL
# Entity: Soho; NER tag: LOC
# Entity: Brownstone; NER tag: PERSON
# Entity: Park Slope; NER tag: ORG
# Entity: NEW YORK CITY; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: CENTRAL PARK & METRO; NER tag: ORG
# Entity: COMFY 1BDR W/CHARACTER!; NER tag: ORG
# Entity: Chelsea Studio; NER tag: ORG
# Entity: 1 - 2 months; NER tag: DATE
# Entity: LUX APT; NER tag: ORG
# Entity: TIMES SQUARE NEW BUILDING; NER tag: FAC
# Entity: Terrace- Spectacular Views; NER tag: ORG
# Entity: Lovely Apt & Garden; NER tag: ORG
# Entity: Best Area; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: 2; NER tag: CARDINAL
# Entity: Lower East Side; NER tag: ORG
# Entity: 57~/night; NER tag: MONEY
# Entity: Manhattan; NER tag: GPE
# Entity: Midtown Manhattan; NER tag: PERSON
# Entity: 2BR; NER tag: CARDINAL
# Entity: 3; NER tag: CARDINAL
# Entity: Williamsburg; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Sml Rm; NER tag: PERSON
# Entity: Cozy; NER tag: GPE
# Entity: Yankee Stadium; NER tag: FAC
# Entity: Brownstone; NER tag: PERSON
# Entity: NOHO; NER tag: ORG
# Entity: EAST VILLAGE; NER tag: GPE
# Entity: Sleek & Comfortable Soho Apt; NER tag: ORG
# Entity: LOFT BED; NER tag: PERSON
# Entity: Cozy 2; NER tag: PERSON
# Entity: Fort Greene; NER tag: GPE
# Entity: Cozy East Village Railroad; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Bedroom Loft w/; NER tag: PERSON
# Entity: Roof Deck; NER tag: PERSON
# Entity: Room - Private & Comfy Bedroom; NER tag: ORG
# Entity: Clean &; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: Cobble Hill; NER tag: LOC
# Entity: East Village; NER tag: GPE
# Entity: Quiet & Clean Retreat; NER tag: ORG
# Entity: Stylish Large Gramercy Loft; NER tag: PERSON
# Entity: The Brownstone-Luxury 1 Bd Apt/NYC; NER tag: ORG
# Entity: 17; NER tag: CARDINAL
# Entity: Manhattan Views; NER tag: ORG
# Entity: Nr; NER tag: ORG
# Entity: Subway; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: Adorable Clean Quiet; NER tag: ORG
# Entity: 3BR; NER tag: CARDINAL
# Entity: Franklin St Flat; NER tag: PERSON
# Entity: Trendy Greenpoint Brooklyn; NER tag: PERSON
# Entity: Cozy; NER tag: GPE
# Entity: Spacious w/; NER tag: PERSON
# Entity: Sleeps; NER tag: PERSON
# Entity: One; NER tag: CARDINAL
# Entity: Apt; NER tag: GPE
# Entity: NYC; NER tag: LOC
# Entity: 3; NER tag: CARDINAL
# Entity: SOHO; NER tag: ORG
# Entity: SpaHa Studio Monthly Rental; NER tag: ORG
# Entity: Harlem; NER tag: LOC
# Entity: the East Village; NER tag: LOC
# Entity: ACCOMMODATIONS GALORE; NER tag: ORG
# Entity: 2; NER tag: MONEY
# Entity: Chelsea Loft; NER tag: PERSON
# Entity: LES; NER tag: ORG
# Entity: apt w. elevato; NER tag: PERSON
# Entity: BK; NER tag: ORG
# Entity: Sweet Suite; NER tag: PERSON
# Entity: Great East Village Apartment Rental; NER tag: ORG
# Entity: NY; NER tag: GPE
# Entity: The Village; NER tag: GPE
# Entity: NYC; NER tag: LOC
# Entity: Duplex; NER tag: GPE
# Entity: Queen Bed; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: & Manhattan NY NY; NER tag: ORG
# Entity: Cozy Private Bedroom; NER tag: ORG
# Entity: duplex; NER tag: GPE
# Entity: DOMINIQUE; NER tag: ORG
# Entity: NY; NER tag: ORG
# Entity: Private, Large & Sunny Top Floor Apt  w/W&D; NER tag: ORG
# Entity: BEDROOM1; NER tag: CARDINAL
# Entity: 10min; NER tag: CARDINAL
# Entity: Manhan; NER tag: GPE
# Entity: SUNNY; NER tag: ORG
# Entity: SPACIOUS NYC; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: soho; NER tag: LOC
# Entity: East Village; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: BROOKLYN; NER tag: GPE
# Entity: BEDROOM2; NER tag: DATE
# Entity: 10min; NER tag: CARDINAL
# Entity: Manh; NER tag: ORG
# Entity: Crown Heights; NER tag: PRODUCT
# Entity: Amazing  Sunny & Breezy Home In; NER tag: ORG
# Entity: NYC; NER tag: LOC
# Entity: 75; NER tag: MONEY
# Entity: 1; NER tag: CARDINAL
# Entity: 2; NER tag: CARDINAL
# Entity: Bedford; NER tag: GPE
# Entity: Williamsburg; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: BR; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: Harlem; NER tag: LOC
# Entity: Private Rm; NER tag: ORG
# Entity: Hosted Apt; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Bedroom Brownstone; NER tag: PERSON
# Entity: East Village; NER tag: GPE
# Entity: Piano & Patio; NER tag: ORG
# Entity: Lower East Side Magic Room; NER tag: ORG
# Entity: Williamsburg Apt*; NER tag: PERSON
# Entity: Central Park; NER tag: LOC
# Entity: 1BR; NER tag: CARDINAL
# Entity: Cozy Garden Apartment; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: SoHa; NER tag: ORG
# Entity: NW Central Park; NER tag: LOC
# Entity: Cozy; NER tag: GPE
# Entity: Upper West Side; NER tag: FAC
# Entity: Cozy Private Room in Apartment; NER tag: ORG
# Entity: Prewar Penthouse w Private Terrace; NER tag: ORG
# Entity: 2.5 BR Loft; NER tag: PERSON
# Entity: Carroll Gardens; NER tag: LOC
# Entity: Subway; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Bowery; NER tag: PRODUCT
# Entity: Brooklyn Writer's Nook; NER tag: ORG
# Entity: Sunny Room East Village NYC; NER tag: PERSON
# Entity: 3; NER tag: CARDINAL
# Entity: Sugar Hill; NER tag: FAC
# Entity: 1 bdrm; NER tag: QUANTITY
# Entity: LES; NER tag: ORG
# Entity: One; NER tag: CARDINAL
# Entity: West Village -; NER tag: GPE
# Entity: Gigantic Private; NER tag: ORG
# Entity: Brooklyn Loft; NER tag: PERSON
# Entity: Condo Apartment; NER tag: PERSON
# Entity: 1BR; NER tag: CARDINAL
# Entity: Central Park; NER tag: LOC
# Entity: Terrace; NER tag: ORG
# Entity: Food & Music Dream Apartment; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: French Garden; NER tag: LOC
# Entity: Bedford; NER tag: GPE
# Entity: Alcove Studio w/; NER tag: PERSON
# Entity: Deck; NER tag: PERSON
# Entity: 3; NER tag: CARDINAL
# Entity: 2; NER tag: CARDINAL
# Entity: Harlem; NER tag: LOC
# Entity: One; NER tag: CARDINAL
# Entity: Bedroom Mini; NER tag: PERSON
# Entity: Sunlit; NER tag: PERSON
# Entity: Cozy Williamsburg/Greenpoint; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Williamsburg; NER tag: GPE
# Entity: Cozy Chinatown Studio Apt; NER tag: PERSON
# Entity: Eveland the Place to Stay & Enjoy; NER tag: ORG
# Entity: Superior @ Box House; NER tag: ORG
# Entity: Hells; NER tag: ORG
# Entity: Historic House; NER tag: PERSON
# Entity: Boerum Hill; NER tag: PERSON
# Entity: BK; NER tag: ORG
# Entity: NYC; NER tag: ORG
# Entity: 3; NER tag: CARDINAL
# Entity: Italianate Brownstone; NER tag: FAC
# Entity: Williamsburg HUGE; NER tag: ORG
# Entity: Cozy; NER tag: GPE
# Entity: East Village; NER tag: GPE
# Entity: AC; NER tag: ORG
# Entity: Duplex; NER tag: GPE
# Entity: Loft w/ Terrace @ Box House; NER tag: PERSON
# Entity: 3; NER tag: CARDINAL
# Entity: Park Slope; NER tag: ORG
# Entity: Loft w/ Terrace @ Box House; NER tag: PERSON
# Entity: Columbia Castle; NER tag: PERSON
# Entity: Brooklyn Heights; NER tag: GPE
# Entity: Columbia Castle 2 BR; NER tag: PERSON
# Entity: Charming Artist's Flat; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Brooklyn; NER tag: GPE
# Entity: Williamsburg; NER tag: PERSON
# Entity: roof cabana; NER tag: PERSON
# Entity: East Village Designer's; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: APT; NER tag: ORG
# Entity: Superior @ Box House; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Large Studio; NER tag: PERSON
# Entity: East Village; NER tag: GPE
# Entity: Garden 1BR/1BA Brownstone Apt - 2; NER tag: ORG
# Entity: MODERN SPACIOUS 2; NER tag: ORG
# Entity: WONDERFUL; NER tag: ORG
# Entity: COMFORTABLE; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Astoria; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: 1BR; NER tag: CARDINAL
# Entity: 2BR; NER tag: CARDINAL
# Entity: Warm & Spacious; NER tag: ORG
# Entity: 1.5BR; NER tag: CARDINAL
# Entity: 1BR; NER tag: CARDINAL
# Entity: WBurg; NER tag: ORG
# Entity: Spacious Loft; NER tag: PERSON
# Entity: Clinton Hill; NER tag: GPE
# Entity: The Brooklyn Waverly; NER tag: ORG
# Entity: One; NER tag: CARDINAL
# Entity: LOVELY APARTMENT; NER tag: PERSON
# Entity: NY; NER tag: GPE
# Entity: Groovy NYC Chelsea Pad; NER tag: ORG
# Entity: Cozy Space; NER tag: PERSON
# Entity: El Barrio; NER tag: GPE
# Entity: Sunny Bklyn Jewel  Fort Greene; NER tag: PERSON
# Entity: JULY; NER tag: DATE
# Entity: 2019; NER tag: DATE
# Entity: MANHATTAN Neat; NER tag: ORG
# Entity: Nice; NER tag: GPE
# Entity: 1BR; NER tag: CARDINAL
# Entity: UWS Brownstone; NER tag: ORG
# Entity: Artsy TopFloor Apt; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: BOHEMIAN EAST; NER tag: LOC
# Entity: 2; NER tag: CARDINAL
# Entity: Rockaway; NER tag: GPE
# Entity: Townhouse; NER tag: GPE
# Entity: Sweet Historic Greenpoint Duplex; NER tag: PERSON
# Entity: Fire Place; NER tag: ORG
# Entity: Nomad/Chelsea Loft Studio; NER tag: ORG
# Entity: Sunny 3BR Apt Ideal for Family  ; NER tag: ORG
# Entity: Cozy Private Room; NER tag: ORG
# Entity: West Harlem; NER tag: GPE
# Entity: UES Quiet & Spacious 1; NER tag: ORG
# Entity: 4; NER tag: CARDINAL
# Entity: Crown Heights; NER tag: PRODUCT
# Entity: Cozy; NER tag: GPE
# Entity: Time Square; NER tag: FAC
# Entity: Duplex; NER tag: GPE
# Entity: Manhattan Studio; NER tag: ORG
# Entity: Hamilton Hts Jewel   ; NER tag: PERSON
# Entity: 1; NER tag: CARDINAL
# Entity: Conveniently Located; NER tag: ORG
# Entity: Stuyvesant Heights; NER tag: GPE
# Entity: Meatpacking & Chelsea; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: Williamsburg; NER tag: PERSON
# Entity: Spacious Brooklyn Loft - 2 Bedroom; NER tag: PERSON
# Entity: Park Slope Apt:; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: NYC Studio for Rent; NER tag: ORG
# Entity: NY; NER tag: GPE
# Entity: Hottest Street; NER tag: LOC
# Entity: New York City; NER tag: GPE
# Entity: ☆; NER tag: CARDINAL
# Entity: DUPLEX; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: 9; NER tag: CARDINAL
# Entity: 2BA; NER tag: CARDINAL
# Entity: Nr; NER tag: ORG
# Entity: Cozy; NER tag: PERSON
# Entity: Bright One Bedroom; NER tag: ORG
# Entity: BK; NER tag: ORG
# Entity: Forest Hills Apt minutes; NER tag: PERSON
# Entity: Manhattan; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Summer Haven; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Spacious Designer's; NER tag: ORG
# Entity: Sunny; NER tag: PERSON
# Entity: one; NER tag: CARDINAL
# Entity: Truly Amazing Oasis In; NER tag: ORG
# Entity: Holiday Time; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: King-Sized; NER tag: ORG
# Entity: Charmer; NER tag: ORG
# Entity: Architect's Brownstone; NER tag: ORG
# Entity: EAST VILLAGE; NER tag: GPE
# Entity: HORIZON; NER tag: ORG
# Entity: 4; NER tag: CARDINAL
# Entity: Bdrm; NER tag: ORG
# Entity: Parisian; NER tag: NORP
# Entity: Chelsea; NER tag: GPE
# Entity: Cozy 2 Bedroom; NER tag: PERSON
# Entity: Three; NER tag: CARDINAL
# Entity: Duplex; NER tag: GPE
# Entity: NYC - Sunny Greenwich Village; NER tag: ORG
# Entity: 1br; NER tag: TIME
# Entity: Loft; NER tag: PERSON
# Entity: Best City Area; NER tag: GPE
# Entity: Park Avenue; NER tag: FAC
# Entity: Artsy 1; NER tag: PRODUCT
# Entity: Apt; NER tag: GPE
# Entity: 20; NER tag: CARDINAL
# Entity: 42nd Grand; NER tag: FAC
# Entity: Astoria-Private Home; NER tag: ORG
# Entity: COMFY; NER tag: ORG
# Entity: APT; NER tag: ORG
# Entity: YARD; NER tag: ORG
# Entity: Park Slope Apartment; NER tag: ORG
# Entity: Cozy; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Greenpoint Spacious Loft; NER tag: PERSON
# Entity: Harlem/; NER tag: ORG
# Entity: Hamilton Heights; NER tag: PERSON
# Entity: Cozy Room; NER tag: PERSON
# Entity: Hancock Town; NER tag: PERSON
# Entity: Entire Apt; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: Clinton Hill + Free Coffee; NER tag: PERSON
# Entity: smile; NER tag: PERSON
# Entity: Nice; NER tag: GPE
# Entity: Greenpoint; NER tag: ORG
# Entity: BK; NER tag: ORG
# Entity: 2/3; NER tag: CARDINAL
# Entity: 1450; NER tag: MONEY
# Entity: two; NER tag: CARDINAL
# Entity: Brownstone; NER tag: GPE
# Entity: 1355; NER tag: MONEY
# Entity: Chelsea; NER tag: ORG
# Entity: 2BR; NER tag: CARDINAL
# Entity: 60; NER tag: CARDINAL
# Entity: East Village; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: NYC; NER tag: LOC
# Entity: Manhattan Penthouse-Max.12; NER tag: ORG
# Entity: 3; NER tag: CARDINAL
# Entity: Deck; NER tag: PERSON
# Entity: Awesome Artist's; NER tag: ORG
# Entity: Cool & Spacious Harlem Artist Flat; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: Sleeps 4 ☆; NER tag: PERSON
# Entity: Greenpoint Loft / Le Chez Andrea; NER tag: PERSON
# Entity: Peaceful Bedroom; NER tag: PERSON
# Entity: Amazing Brownstone; NER tag: ORG
# Entity: Best Brooklyn; NER tag: GPE
# Entity: Curtain; NER tag: ORG
# Entity: Nice Manhattan Apt Near Central Park; NER tag: ORG
# Entity: Subway; NER tag: GPE
# Entity: LG Private Room/Family Friendly; NER tag: ORG
# Entity: Midtown; NER tag: GPE
# Entity: 3; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: Duplex; NER tag: GPE
# Entity: AC; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: Sunny; NER tag: ORG
# Entity: Brownstone; NER tag: GPE
# Entity: UWS; NER tag: ORG
# Entity: Modern Space in; NER tag: ORG
# Entity: Warehouse Loft; NER tag: PERSON
# Entity: Garden; NER tag: GPE
# Entity: Affordable & Cozy; NER tag: ORG
# Entity: Creative Vintage Loft; NER tag: PERSON
# Entity: S. Williamsburg; NER tag: GPE
# Entity: Downtown Awesome Private Apartment; NER tag: ORG
# Entity: Fort Greene; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Sunny; NER tag: ORG
# Entity: Lower East Side; NER tag: LOC
# Entity: Cozy Pre-War Harlem Apartment; NER tag: PERSON
# Entity: Elegant 2-BR; NER tag: PERSON
# Entity: Union Square; NER tag: FAC
# Entity: Cozy; NER tag: PERSON
# Entity: Bushwick; NER tag: GPE
# Entity: Cosy Sunny; NER tag: PERSON
# Entity: Prospect Heights; NER tag: GPE
# Entity: East Village; NER tag: GPE
# Entity: Williamsburg Home Away From Home; NER tag: PERSON
# Entity: Brand New Beautiful Duplex Apartment; NER tag: ORG
# Entity: Luxury; NER tag: PERSON
# Entity: Chelsea; NER tag: GPE
# Entity: LES; NER tag: ORG
# Entity: Spring &; NER tag: ORG
# Entity: Mulberry 2 Bedroom Apartment; NER tag: PERSON
# Entity: Ultra Modern NYC Garden Apartment; NER tag: ORG
# Entity: NYC; NER tag: LOC
# Entity: Entire Manhattan Townhouse; NER tag: ORG
# Entity: Cozy studio Apartment in Upper East; NER tag: ORG
# Entity: NYU; NER tag: ORG
# Entity: SPECIAL$; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: Bedford Ave; NER tag: ORG
# Entity: WEST VILLAGE LRG CLEAN SUNNY PRIVATE BDRM; NER tag: ORG
# Entity: Historic Brooklyn Studio Apartment; NER tag: PERSON
# Entity: The Oasis; NER tag: WORK_OF_ART
# Entity: Bedford Williamsburg; NER tag: PERSON
# Entity: 1BR; NER tag: CARDINAL
# Entity: BEAUTIFUL; NER tag: ORG
# Entity: Kitchen Funky 80's; NER tag: PERSON
# Entity: Hideaway; NER tag: ORG
# Entity: New York City; NER tag: GPE
# Entity: Spacious & Comfy BK Brownstone; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: Beautiful Grdn; NER tag: PERSON
# Entity: Park Slope; NER tag: ORG
# Entity: East Village Penthouse; NER tag: ORG
# Entity: Columbus; NER tag: NORP
# Entity: Luxury Bldg - Private; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: Bedford L; NER tag: ORG
# Entity: Kid-Friendly; NER tag: ORG
# Entity: 15-20; NER tag: CARDINAL
# Entity: Midtown; NER tag: GPE
# Entity: Chelsea Studio; NER tag: PERSON
# Entity: 5; NER tag: CARDINAL
# Entity: Cozy,Clean & Legal; NER tag: ORG
# Entity: Loft Style Apt; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Sunny, Large; NER tag: ORG
# Entity: Bklyn Loft; NER tag: PERSON
# Entity: drman bldg; NER tag: PERSON
# Entity: Cozy; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Hamilton Heights; NER tag: GPE
# Entity: Sunny Space; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: STYLISH EAST VILLAGE FLAT; NER tag: ORG
# Entity: Serene Park Slope Garden Apartment; NER tag: ORG
# Entity: Cozy; NER tag: PERSON
# Entity: NYC; NER tag: ORG
# Entity: James Pl Garden Studio; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: Midtown; NER tag: GPE
# Entity: Ideal Brooklyn Brownstone Apartment; NER tag: ORG
# Entity: Bushwick; NER tag: GPE
# Entity: NY; NER tag: ORG
# Entity: Private Entrance - Private Parking; NER tag: ORG
# Entity: Yankee Stadium Oasis 2; NER tag: FAC
# Entity: Manhattan; NER tag: GPE
# Entity: Spacious Studio; NER tag: PERSON
# Entity: Brick Loft; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Bed-Stuy; NER tag: PERSON
# Entity: Sunnyside NYC/ AC; NER tag: ORG
# Entity: Midtown; NER tag: GPE
# Entity: East Village House; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Greenwich Village; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: One; NER tag: CARDINAL
# Entity: CreaTive Live-In; NER tag: PERSON
# Entity: DesignSponge; NER tag: ORG
# Entity: New Clean Spacious Bed & Breakfast; NER tag: ORG
# Entity: Sunny; NER tag: ORG
# Entity: Victorian; NER tag: NORP
# Entity: Unique Studio; NER tag: PERSON
# Entity: NYC; NER tag: LOC
# Entity: 2 Bed; NER tag: PERSON
# Entity: 1; NER tag: CARDINAL
# Entity: Bay Ridge; NER tag: GPE
# Entity: the Upper West Side; NER tag: FAC
# Entity: Wonderful Studio; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: NY; NER tag: GPE
# Entity: Cozy Brooklyn Hideaway; NER tag: ORG
# Entity: Harlem; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Bed + Study; NER tag: PERSON
# Entity: Chic Quiet; NER tag: PERSON
# Entity: 1BR; NER tag: CARDINAL
# Entity: 1; NER tag: CARDINAL
# Entity: Flatiron; NER tag: ORG
# Entity: 3; NER tag: MONEY
# Entity: NYC; NER tag: ORG
# Entity: Artsy Loft; NER tag: PERSON
# Entity: Harlem Apartment; NER tag: FAC
# Entity: Harlem/Manhattan Classic Apartment; NER tag: ORG
# Entity: Victorian; NER tag: NORP
# Entity: Brooklyn B & B; NER tag: ORG
# Entity: Manhattan; NER tag: GPE
# Entity: The Notorious B.N.B.; NER tag: ORG
# Entity: Sunny 2; NER tag: PRODUCT
# Entity: Duplex; NER tag: GPE
# Entity: 3; NER tag: CARDINAL
# Entity: Alpha-Bet City; NER tag: ORG
# Entity: 2br; NER tag: ORDINAL
# Entity: Kid-Friendly 2 BR; NER tag: ORG
# Entity: West Village; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Beautiful Brownstone; NER tag: PERSON
# Entity: 1BDR; NER tag: CARDINAL
# Entity: Park Slope; NER tag: ORG
# Entity: EmpireState; NER tag: ORG
# Entity: Yankee Stadium Pad 5 Minutes; NER tag: WORK_OF_ART
# Entity: Manhattan; NER tag: GPE
# Entity: East Village; NER tag: GPE
# Entity: One; NER tag: CARDINAL
# Entity: Soho; NER tag: LOC
# Entity: NYC Studio; NER tag: ORG
# Entity: Times Square; NER tag: FAC
# Entity: Queens; NER tag: GPE
# Entity: Garden; NER tag: GPE
# Entity: Loft Bed; NER tag: PERSON
# Entity: 4; NER tag: CARDINAL
# Entity: Stylish Studio; NER tag: PERSON
# Entity: Terrace; NER tag: ORG
# Entity: LES; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Garden Home; NER tag: ORG
# Entity: 5 minutes; NER tag: TIME
# Entity: Manhattan; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Brooklyn; NER tag: GPE
# Entity: 2bdrm; NER tag: CARDINAL
# Entity: East Village; NER tag: GPE
# Entity: LOCATION LOCATION; NER tag: PERSON
# Entity: LOCATION Liz's; NER tag: PERSON
# Entity: Manhattan Loft; NER tag: PERSON
# Entity: Astoria Garden Suite; NER tag: ORG
# Entity: Lower East Side/Chinatown 1 Bedroom; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Newyorkr; NER tag: PERSON
# Entity: Fort Green; NER tag: FAC
# Entity: BK; NER tag: ORG
# Entity: Spacious & Charming; NER tag: ORG
# Entity: The Notorious B.N.B.; NER tag: ORG
# Entity: Clinton Hill 1 Bed; NER tag: PERSON
# Entity: Great Studio; NER tag: PERSON
# Entity: W. Village - NYC; NER tag: GPE
# Entity: The Notorious B.N.B.; NER tag: ORG
# Entity: 2BR; NER tag: CARDINAL
# Entity: Williamsburg; NER tag: GPE
# Entity: One; NER tag: CARDINAL
# Entity: 2; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: Brooklyn Brownstone; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Crown Heights; NER tag: GPE
# Entity: Sweet Apt; NER tag: PERSON
# Entity: Cozy Studio; NER tag: PERSON
# Entity: Subway; NER tag: ORG
# Entity: Scandinavian; NER tag: NORP
# Entity: up to 5; NER tag: CARDINAL
# Entity: LES; NER tag: ORG
# Entity: Loft Suite @ Box; NER tag: PERSON
# Entity: 4; NER tag: CARDINAL
# Entity: WEST VILLAGE; NER tag: GPE
# Entity: 900ft² 1br; NER tag: DATE
# Entity: WV; NER tag: GPE
# Entity: Pre-War; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: My Two Bedroom Flat; NER tag: ORG
# Entity: SPACIOUS PRIVATE LITTLE ITALY FLAT; NER tag: ORG
# Entity: Harlem; NER tag: LOC
# Entity: Harlem; NER tag: LOC
# Entity: Greenwich Village; NER tag: GPE
# Entity: Williamsburg Loft; NER tag: PERSON
# Entity: Bedford; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Ctrl Prk; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: NYC; NER tag: LOC
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Brighton  Beach; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: UWS; NER tag: ORG
# Entity: Chez Carine - Privacy; NER tag: ORG
# Entity: Manhattan; NER tag: GPE
# Entity: Loft Suite @ Box; NER tag: PERSON
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Duplex; NER tag: GPE
# Entity: Loft w/ Terrace @ Box House; NER tag: PERSON
# Entity: 1; NER tag: CARDINAL
# Entity: Superior @ Box House; NER tag: ORG
# Entity: BR; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Husband & Wife Art-Filled Apartment; NER tag: ORG
# Entity: 3BR; NER tag: CARDINAL
# Entity: 2; NER tag: CARDINAL
# Entity: Bushwick; NER tag: GPE
# Entity: Cozy 2 Bedroom; NER tag: PERSON
# Entity: City; NER tag: GPE
# Entity: NOLITA; NER tag: ORG
# Entity: NYC; NER tag: ORG
# Entity: Queens; NER tag: GPE
# Entity: 15; NER tag: CARDINAL
# Entity: Times Square; NER tag: FAC
# Entity: Luxury Chelsea Townhouse; NER tag: PERSON
# Entity: the High Line; NER tag: FAC
# Entity: Alchemy BnB; NER tag: ORG
# Entity: 2br; NER tag: ORDINAL
# Entity: NYC; NER tag: LOC
# Entity: JFK & LGA; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: CHELSEA 1 Bdrm Plus Sleeping Loft; NER tag: ORG
# Entity: Manhattan; NER tag: GPE
# Entity: Fort Greene; NER tag: GPE
# Entity: 1BR-; NER tag: CARDINAL
# Entity: SUBLET; NER tag: ORG
# Entity: NewYork Modern Pre-War LoftStudio; NER tag: ORG
# Entity: Cozy Artist; NER tag: PERSON
# Entity: NYC; NER tag: LOC
# Entity: Chelsea/West Village - 2bdrm; NER tag: ORG
# Entity: 1500+ sq ft; NER tag: DATE
# Entity: 2BR; NER tag: CARDINAL
# Entity: West Village; NER tag: GPE
# Entity: Cozy & Clean Lower East Side Apt; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Chic + Stylish; NER tag: PERSON
# Entity: NYC; NER tag: LOC
# Entity: 2; NER tag: CARDINAL
# Entity: 2; NER tag: CARDINAL
# Entity: East Village; NER tag: GPE
# Entity: City Skyline Views; NER tag: ORG
# Entity: Contemporary & Classic Sanctuary; NER tag: ORG
# Entity: Hudson; NER tag: LOC
# Entity: Manhattanville; NER tag: GPE
# Entity: JFK/LGA; NER tag: ORG
# Entity: Hell; NER tag: ORG
# Entity: Luxury NYC 2 Bedroom; NER tag: ORG
# Entity: Terrace; NER tag: ORG
# Entity: Soho; NER tag: LOC
# Entity: 2; NER tag: CARDINAL
# Entity: Loft; NER tag: PERSON
# Entity: Bedford L; NER tag: ORG
# Entity: Central Park; NER tag: LOC
# Entity: One; NER tag: CARDINAL
# Entity: SUNNY; NER tag: ORG
# Entity: 1 Bedroom APT; NER tag: PRODUCT
# Entity: Fort Greene; NER tag: GPE
# Entity: West Village; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: NYC; NER tag: LOC
# Entity: 2; NER tag: CARDINAL
# Entity: LOFT; NER tag: ORG
# Entity: Sunny Bedroom; NER tag: PERSON
# Entity: Bronx; NER tag: GPE
# Entity: SUNNY; NER tag: ORG
# Entity: Uptwn; NER tag: ORG
# Entity: Centrl Park; NER tag: FAC
# Entity: Williamsburg; NER tag: GPE
# Entity: Hudson Yards; NER tag: PERSON
# Entity: The Highline Park; NER tag: WORK_OF_ART
# Entity: One; NER tag: CARDINAL
# Entity: Midtown Manhattan; NER tag: ORG
# Entity: Bushwick; NER tag: ORG
# Entity: Cozy New York  City; NER tag: ORG
# Entity: Royal Room; NER tag: ORG
# Entity: SUPER CUTE; NER tag: ORG
# Entity: BEDFORD AV; NER tag: ORG
# Entity: Sleep & Wake; NER tag: ORG
# Entity: Botanical Gardens; NER tag: FAC
# Entity: Brooklyn; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Midtown; NER tag: GPE
# Entity: 1BR; NER tag: CARDINAL
# Entity: Central Park; NER tag: LOC
# Entity: 1; NER tag: CARDINAL
# Entity: Entire Apt; NER tag: PERSON
# Entity: 1 yr-6 months; NER tag: DATE
# Entity: Greenpoint; NER tag: GPE
# Entity: SUNNY; NER tag: ORG
# Entity: SPACIOUS APT; NER tag: ORG
# Entity: GREENE; NER tag: ORG
# Entity: 6; NER tag: CARDINAL
# Entity: West Village; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Clinton Hill; NER tag: PERSON
# Entity: Brooklyn Apt; NER tag: PERSON
# Entity: Studio-Loft; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Carlton; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Duplex; NER tag: GPE
# Entity: Manhattanville; NER tag: GPE
# Entity: 1800; NER tag: DATE
# Entity: East Village Apt; NER tag: GPE
# Entity: Sunny Entire Apt; NER tag: PERSON
# Entity: Manhattan; NER tag: GPE
# Entity: West Village NYC Sun; NER tag: GPE
# Entity: Studio; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: #1; NER tag: MONEY
# Entity: Cozy Brownstone Inn I(studio; NER tag: PERSON
# Entity: Crown Height's; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Cozy Apt; NER tag: PERSON
# Entity: West Village; NER tag: GPE
# Entity: 2br; NER tag: ORDINAL
# Entity: Loft; NER tag: PERSON
# Entity: Kensington/Ditmas Park; NER tag: ORG
# Entity: Sunny Town House; NER tag: ORG
# Entity: 18; NER tag: CARDINAL
# Entity: Cozy & Charming Boerum Hill Flat; NER tag: ORG
# Entity: Park Slope; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Sunny Bedroom; NER tag: PERSON
# Entity: One; NER tag: CARDINAL
# Entity: Bathroom; NER tag: ORG
# Entity: Williamsburg Loft; NER tag: PERSON
# Entity: Stylish Garden House - Trendy; NER tag: PERSON
# Entity: Hells; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Pre War Park Slope; NER tag: ORG
# Entity: Charming Apt; NER tag: PERSON
# Entity: 1; NER tag: CARDINAL
# Entity: NYC View; NER tag: LOC
# Entity: L; NER tag: GPE
# Entity: Charming Brooklyn Studio; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Kitchen Studio; NER tag: PERSON
# Entity: 20 AND; NER tag: DATE
# Entity: 30; NER tag: CARDINAL
# Entity: Cozy, Clean Cobble Hill Brownstone; NER tag: ORG
# Entity: Loft Apt w; NER tag: PERSON
# Entity: Skylight; NER tag: GPE
# Entity: Wburg; NER tag: GPE
# Entity: Cozy; NER tag: GPE
# Entity: Garden; NER tag: GPE
# Entity: Sunny 1BR Center of East Village; NER tag: ORG
# Entity: 2BR; NER tag: CARDINAL
# Entity: Cobble Hill; NER tag: LOC
# Entity: Brooklyn; NER tag: GPE
# Entity: NY; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Zen Minimalist w; NER tag: PERSON
# Entity: BIG; NER tag: ORG
# Entity: LINCOLN CENTER AREA; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Astoria; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: West Village; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Midtown West; NER tag: GPE
# Entity: One; NER tag: CARDINAL
# Entity: Columbia Uni; NER tag: ORG
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: NYC Summer; NER tag: LOC
# Entity: 2BR; NER tag: CARDINAL
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Loft Suite @ Box; NER tag: PERSON
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Loft Suite; NER tag: PERSON
# Entity: The Box House Hotel; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: BK; NER tag: ORG
# Entity: Williamsburg HUGE SUNNY; NER tag: ORG
# Entity: Loft Suite @ Box; NER tag: PERSON
# Entity: Sunny; NER tag: ORG
# Entity: Whole Apt; NER tag: PERSON
# Entity: Williamsburg; NER tag: PERSON
# Entity: Queens; NER tag: GPE
# Entity: Sublet; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Cozy Corner; NER tag: PERSON
# Entity: Bedford Ave  Brooklyn; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Apt; NER tag: GPE
# Entity: Wburg; NER tag: GPE
# Entity: BK; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: Bklyn; NER tag: PERSON
# Entity: Bdrm Apt; NER tag: PERSON
# Entity: 1BD; NER tag: CARDINAL
# Entity: SoHo; NER tag: LOC
# Entity: Greenpoint; NER tag: GPE
# Entity: Sunny 1BR East; NER tag: ORG
# Entity: 1B/1BTH; NER tag: CARDINAL
# Entity: GEM; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Central Park; NER tag: LOC
# Entity: Grand; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Giant Sunny Bedroom & Private Bath; NER tag: ORG
# Entity: Backyard &; NER tag: ORG
# Entity: Unique; NER tag: PERSON
# Entity: Home, Stapleton; NER tag: ORG
# Entity: SI; NER tag: ORG
# Entity: Sunny Bedroom; NER tag: PERSON
# Entity: Harlem/Hamilton Heights Sunny Room; NER tag: ORG
# Entity: Clinton Hill Duplex; NER tag: PERSON
# Entity: Pratt; NER tag: GPE
# Entity: Sunny 1 BR; NER tag: PRODUCT
# Entity: 80s; NER tag: DATE
# Entity: 2; NER tag: CARDINAL
# Entity: 2ND; NER tag: CARDINAL
# Entity: AVENUE; NER tag: ORG
# Entity: NYC; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: Historic Brooklyn 2-Bedroom Apt; NER tag: PERSON
# Entity: APT; NER tag: ORG
# Entity: 1200sf; NER tag: ORDINAL
# Entity: Brooklyn; NER tag: GPE
# Entity: Cozy Nook; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: Historic Loft; NER tag: PERSON
# Entity: Range; NER tag: LOC
# Entity: Amazing Park Slope Duplex; NER tag: ORG
# Entity: Deck; NER tag: PERSON
# Entity: Entire 2 Bedroom Apartment; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: Baby Nursery; NER tag: ORG
# Entity: Private Manhattan Studio; NER tag: ORG
# Entity: Luxury Williamsburg; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Artist Loft-McCarren Park-Williamsburg-BrooklynNYC; NER tag: PERSON
# Entity: Chelsea/Meat Packing  Artist Space; NER tag: ORG
# Entity: Bedroom - Williamsburg; NER tag: PERSON
# Entity: MET Museum; NER tag: ORG
# Entity: Loft; NER tag: PERSON
# Entity: Cozy Upper East Side Studio; NER tag: ORG
# Entity: 2; NER tag: MONEY
# Entity: Landmark Home 1 Block; NER tag: ORG
# Entity: East Village; NER tag: GPE
# Entity: NY; NER tag: ORG
# Entity: NYC Summer Discount; NER tag: FAC
# Entity: 1; NER tag: CARDINAL
# Entity: Central; NER tag: ORG
# Entity: Spacious Manhattan Apartment; NER tag: ORG
# Entity: Central Park; NER tag: LOC
# Entity: 15min; NER tag: CARDINAL
# Entity: NYC; NER tag: LOC
# Entity: Brooklyn; NER tag: GPE
# Entity: New-York; NER tag: GPE
# Entity: Cozy; NER tag: GPE
# Entity: Times Square; NER tag: FAC
# Entity: Artist's Flat; NER tag: ORG
# Entity: 10263; NER tag: MONEY
# Entity: Harlem; NER tag: LOC
# Entity: Bklyn 6; NER tag: PERSON
# Entity: Bklyn 4; NER tag: PERSON
# Entity: 4; NER tag: CARDINAL
# Entity: 2; NER tag: CARDINAL
# Entity: 1; NER tag: CARDINAL
# Entity: Stylish & Quiet NYC Retreat; NER tag: ORG
# Entity: Lincoln Center Studio; NER tag: ORG
# Entity: Clean&Sunny; NER tag: NORP
# Entity: Super Clean Apt; NER tag: ORG
# Entity: Columbus Circle; NER tag: LOC
# Entity: Brownstone; NER tag: GPE
# Entity: TIMES SQUARE HOUSE; NER tag: ORG
# Entity: West Village; NER tag: GPE
# Entity: 21 day; NER tag: DATE
# Entity: Chelsea Apartment; NER tag: ORG
# Entity: Heavy Sun; NER tag: ORG
# Entity: Arty 1 Bedroom; NER tag: ORG
# Entity: West Village; NER tag: GPE
# Entity: Spacious Lower East Side Apt; NER tag: ORG
# Entity: NYC; NER tag: LOC
# Entity: 2; NER tag: CARDINAL
# Entity: BED; NER tag: ORG
# Entity: GEM; NER tag: ORG
# Entity: Williamsburg Loft; NER tag: PERSON
# Entity: 2BR; NER tag: CARDINAL
# Entity: Park Slope; NER tag: ORG
# Entity: 2BR; NER tag: CARDINAL
# Entity: Botanic Garden; NER tag: LOC
# Entity: Upper East; NER tag: LOC
# Entity: 14; NER tag: MONEY
# Entity: Lower East Side; NER tag: LOC
# Entity: NYC; NER tag: LOC
# Entity: Prospect Park; NER tag: FAC
# Entity: Manhattan; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: 3; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: Park Slope; NER tag: ORG
# Entity: Eastern Parkway Brooklyn 1BR; NER tag: FAC
# Entity: 1400sf; NER tag: ORDINAL
# Entity: Manhattan View Artistic Loft; NER tag: EVENT
# Entity: Williamsburg; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: 2BD/2BTH; NER tag: CARDINAL
# Entity: 2BD; NER tag: DATE
# Entity: Backyard; NER tag: PERSON
# Entity: Williamsbrg; NER tag: GPE
# Entity: Sunny Retreat; NER tag: ORG
# Entity: Roof Garden; NER tag: PERSON
# Entity: Enjoy Staten; NER tag: PERSON
# Entity: Cozy 2 BD; NER tag: PERSON
# Entity: Midtown West; NER tag: GPE
# Entity: Park Slope; NER tag: ORG
# Entity: Sunny Studio; NER tag: PERSON
# Entity: Luxury L-Shape Studio + 3; NER tag: PERSON
# Entity: Cozy; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Inwood Manhattan; NER tag: ORG
# Entity: Loft/10; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: New York; NER tag: GPE
# Entity: two; NER tag: CARDINAL
# Entity: 70; NER tag: DATE
# Entity: ST; NER tag: GPE
# Entity: Cozy Room; NER tag: PERSON
# Entity: Cozy; NER tag: PERSON
# Entity: Manhattan; NER tag: GPE
# Entity: LOCATION LOCATION; NER tag: PERSON
# Entity: Quaint & Quiet; NER tag: ORG
# Entity: Queens; NER tag: GPE
# Entity: Williamsburg; NER tag: GPE
# Entity: soho .support; NER tag: FAC
# Entity: Times Square Sanctuary; NER tag: FAC
# Entity: Luxury Building; NER tag: GPE
# Entity: Nolita; NER tag: GPE
# Entity: ArtistLoft; NER tag: ORG
# Entity: Briarwood; NER tag: GPE
# Entity: NY; NER tag: ORG
# Entity: Flatiron-Designer's; NER tag: ORG
# Entity: Stylish Designer Studio; NER tag: PERSON
# Entity: Piano; NER tag: PERSON
# Entity: New York City; NER tag: GPE
# Entity: New York Host; NER tag: GPE
# Entity: One; NER tag: CARDINAL
# Entity: SWEET; NER tag: PERSON
# Entity: 2BR; NER tag: CARDINAL
# Entity: DUPLEX; NER tag: ORG
# Entity: Big Beautiful Railroad; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: 30 day; NER tag: DATE
# Entity: YOGA; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: 1.5; NER tag: CARDINAL
# Entity: Harlem; NER tag: LOC
# Entity: Manhattan; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: East Village; NER tag: GPE
# Entity: Private Garden Entry; NER tag: ORG
# Entity: LUXE Privé L.I.C. Apt & Garden; NER tag: ORG
# Entity: Studio Loft; NER tag: PERSON
# Entity: Williamsburg Apt; NER tag: PERSON
# Entity: TWO; NER tag: CARDINAL
# Entity: BROOKLYN; NER tag: GPE
# Entity: NYC; NER tag: LOC
# Entity: West Village; NER tag: GPE
# Entity: One; NER tag: CARDINAL
# Entity: Brooklyn Brownstone; NER tag: PERSON
# Entity: ProspectPark; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: sunny & artsy; NER tag: ORG
# Entity: 4; NER tag: CARDINAL
# Entity: Simple Perfect Soho; NER tag: WORK_OF_ART
# Entity: 3; NER tag: CARDINAL
# Entity: BR; NER tag: ORG
# Entity: Crown Heights; NER tag: GPE
# Entity: Brownstone Sunny & Spacious; NER tag: ORG
# Entity: Morocco; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Financial District; NER tag: LOC
# Entity: Tree-Lined Windows; NER tag: ORG
# Entity: east village; NER tag: GPE
# Entity: Lush Garden; NER tag: PERSON
# Entity: Quiet 2 BR; NER tag: PERSON
# Entity: Park Slope; NER tag: ORG
# Entity: Cozy; NER tag: GPE
# Entity: 1BR; NER tag: CARDINAL
# Entity: East Village; NER tag: GPE
# Entity: Stylish Loft; NER tag: PERSON
# Entity: Garden - Brownstone; NER tag: ORG
# Entity: NYC; NER tag: LOC
# Entity: 1; NER tag: CARDINAL
# Entity: Times Sq/Midtown W; NER tag: ORG
# Entity: Spacious Loft + Backyard; NER tag: PERSON
# Entity: Zen W. Village Studio; NER tag: PERSON
# Entity: 2BR; NER tag: CARDINAL
# Entity: BK; NER tag: ORG
# Entity: One; NER tag: CARDINAL
# Entity: Central Park View UWS; NER tag: LOC
# Entity: Only 5; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Prospect Heights; NER tag: GPE
# Entity: Spacious & Sunny; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: JFK & City; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Park Slope/Gowanus; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: New Yorkers; NER tag: NORP
# Entity: NEW YORK; NER tag: GPE
# Entity: Sunny West Village Dream; NER tag: ORG
# Entity: SUNNY ZEN  FULL SERVICE HUGE STUDIO; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: Artsy; NER tag: ORG
# Entity: Sunny Bedroom; NER tag: PERSON
# Entity: Harlem; NER tag: LOC
# Entity: Brooklyn; NER tag: GPE
# Entity: Best Area; NER tag: LOC
# Entity: GREAT 1BR/2BA TERRACE & W/D!; NER tag: ORG
# Entity: EV; NER tag: ORG
# Entity: Graham; NER tag: PERSON
# Entity: BK; NER tag: ORG
# Entity: triplex; NER tag: PRODUCT
# Entity: 4BD; NER tag: CARDINAL
# Entity: 20; NER tag: CARDINAL
# Entity: NYC; NER tag: LOC
# Entity: 2.5; NER tag: CARDINAL
# Entity: Brooklyn Brownstone; NER tag: FAC
# Entity: Best Block; NER tag: ORG
# Entity: NYC; NER tag: ORG
# Entity: July 25; NER tag: DATE
# Entity: 18; NER tag: CARDINAL
# Entity: Kips Bay; NER tag: LOC
# Entity: NY; NER tag: ORG
# Entity: Private Artist’s; NER tag: ORG
# Entity: Amazing Location; NER tag: ORG
# Entity: 1 BR; NER tag: QUANTITY
# Entity: Spacious Loft 5; NER tag: PERSON
# Entity: Union Square; NER tag: FAC
# Entity: Duplex; NER tag: GPE
# Entity: Art & Music Salon; NER tag: ORG
# Entity: Duplex; NER tag: GPE
# Entity: 1 bdrm; NER tag: QUANTITY
# Entity: 70's-1; NER tag: CARDINAL
# Entity: Central Park; NER tag: LOC
# Entity: Brooklyn; NER tag: GPE
# Entity: 4; NER tag: CARDINAL
# Entity: New York; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: McCarren Park; NER tag: GPE
# Entity: Exciting Lower East Side; NER tag: ORG
# Entity: Loft Life; NER tag: ORG
# Entity: Cat-Lovers; NER tag: ORG
# Entity: UNION SQUARE❤; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Upper Manhattan; NER tag: LOC
# Entity: Cozy-Singles NYC- Upper; NER tag: PERSON
# Entity: One; NER tag: CARDINAL
# Entity: Chelsea; NER tag: GPE
# Entity: West Village Loft; NER tag: GPE
# Entity: 1st; NER tag: ORDINAL
# Entity: West Village Gem - 2BR; NER tag: GPE
# Entity: Cozy; NER tag: PERSON
# Entity: NYC; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: NYC; NER tag: LOC
# Entity: Harlem; NER tag: LOC
# Entity: Bedford L; NER tag: PERSON
# Entity: Historic 3 Bedroom Eastern Parkway; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: W'burg; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: w/ yard & laundry; NER tag: ORG
# Entity: 5; NER tag: CARDINAL
# Entity: Bedstuy Gem; NER tag: PERSON
# Entity: 1BR; NER tag: CARDINAL
# Entity: LES; NER tag: ORG
# Entity: NY; NER tag: ORG
# Entity: Greenwich Village; NER tag: GPE
# Entity: weeks; NER tag: DATE
# Entity: Studio Apt; NER tag: PERSON
# Entity: Lower East - Manhattan; NER tag: LOC
# Entity: NEW YORK; NER tag: GPE
# Entity: BR; NER tag: PERSON
# Entity: Battery Park; NER tag: GPE
# Entity: South Harlem; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: one; NER tag: CARDINAL
# Entity: Prospect Park; NER tag: ORG
# Entity: Luxury Doorman Bldg Nr; NER tag: PERSON
# Entity: Cozy; NER tag: GPE
# Entity: NYC 1; NER tag: LOC
# Entity: Subway; NER tag: ORG
# Entity: Modern Artist's; NER tag: ORG
# Entity: Columbus Circle; NER tag: LOC
# Entity: Studio Apt; NER tag: PERSON
# Entity: Park; NER tag: GPE
# Entity: CARRIAGE HOUSE STUDIO OFF; NER tag: ORG
# Entity: 2RE; NER tag: CARDINAL
# Entity: NYC; NER tag: ORG
# Entity: ST MARKS PLACE &; NER tag: ORG
# Entity: 1AVE; NER tag: CARDINAL
# Entity: Quiet Apt; NER tag: PERSON
# Entity: Sunny Midtown East Apt w/; NER tag: ORG
# Entity: Carroll Gardens; NER tag: LOC
# Entity: Lux 1 Bed Apt; NER tag: PERSON
# Entity: Best Location; NER tag: ORG
# Entity: Brooklyn Brownstone w/; NER tag: ORG
# Entity: Mini Loft Williamsburg Bkln-Bedford; NER tag: PERSON
# Entity: Sunnyside Gardens; NER tag: LOC
# Entity: Williamsburg; NER tag: PERSON
# Entity: 2b; NER tag: CARDINAL
# Entity: Studio 54; NER tag: ORG
# Entity: Cozy Room; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: Super Cute Junior; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: LES; NER tag: ORG
# Entity: GREAT BRAND; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: BED; NER tag: ORG
# Entity: Perfect &; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Duplex; NER tag: GPE
# Entity: Modern 1br; NER tag: DATE
# Entity: Brooklyn; NER tag: GPE
# Entity: Sunny Apt; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Williamsburg; NER tag: GPE
# Entity: 3; NER tag: CARDINAL
# Entity: Park Slope Townhouse; NER tag: ORG
# Entity: Cozy Love Nest Prospect Heights; NER tag: ORG
# Entity: 3 bdrm; NER tag: QUANTITY
# Entity: 1BR; NER tag: CARDINAL
# Entity: Stylish Large; NER tag: PERSON
# Entity: 1bd; NER tag: ORDINAL
# Entity: APT; NER tag: ORG
# Entity: Chinatown/Tribeca NYC; NER tag: ORG
# Entity: Two; NER tag: CARDINAL
# Entity: loft +roof garden; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: 10min; NER tag: CARDINAL
# Entity: Walk & 15mins; NER tag: ORG
# Entity: Tourist Spot; NER tag: ORG
# Entity: Classic Brooklyn Brownstone; NER tag: PRODUCT
# Entity: 4; NER tag: CARDINAL
# Entity: Carroll Gardens Carriage House; NER tag: ORG
# Entity: Traveler; NER tag: PERSON
# Entity: NYC 30; NER tag: PRODUCT
# Entity: Subway; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: Trendy Nest; NER tag: PERSON
# Entity: the East Village; NER tag: LOC
# Entity: UPWS; NER tag: ORG
# Entity: DUPLEX; NER tag: ORG
# Entity: Private Bdrm & Bath-30-night; NER tag: ORG
# Entity: Wooden; NER tag: GPE
# Entity: Central Park; NER tag: LOC
# Entity: Sunny Rm; NER tag: ORG
# Entity: 1; NER tag: MONEY
# Entity: Air Conditioner; NER tag: PERSON
# Entity: Park; NER tag: PERSON
# Entity: Park Slope; NER tag: ORG
# Entity: One; NER tag: CARDINAL
# Entity: WIlliamsburg Studio; NER tag: PERSON
# Entity: Greenwich Village; NER tag: GPE
# Entity: 1760; NER tag: DATE
# Entity: Retro Apt; NER tag: PERSON
# Entity: UWS; NER tag: ORG
# Entity: Manhattan; NER tag: GPE
# Entity: SPACIOUS Fabulous Sunny Loft; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Fall; NER tag: GPE
# ...
# Entity: Union Square; NER tag: FAC
# Entity: Deck; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: garden &; NER tag: ORG
# Entity: Studio Plus; NER tag: ORG
# Entity: Hilton Grand; NER tag: PERSON
# Entity: ARTSY & CONVENIENT; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: APT; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Williamsburg; NER tag: ORG
# Entity: Sunny; NER tag: GPE
# Entity: Chelsea Apt; NER tag: PERSON
# Entity: Washer/Dryer; NER tag: ORG
# Entity: & Clean; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: APT; NER tag: ORG
# Entity: Chez Humphries; NER tag: ORG
# Entity: Sunny Top Floor Uptown Apartment; NER tag: ORG
# Entity: 2BD; NER tag: CARDINAL
# Entity: COL; NER tag: ORG
# Entity: Central Park; NER tag: LOC
# Entity: Brooklyn; NER tag: GPE
# Entity: 10; NER tag: CARDINAL
# Entity: U Square; NER tag: FAC
# Entity: Hamiliton Heights; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Williamsburg; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: 1896; NER tag: DATE
# Entity: NYC; NER tag: LOC
# Entity: River; NER tag: LOC
# Entity: Central Harlem; NER tag: LOC
# Entity: 4; NER tag: CARDINAL
# Entity: Williamsburg; NER tag: GPE
# Entity: 3; NER tag: CARDINAL
# Entity: Brooklyn; NER tag: GPE
# Entity: Sweet Deal*Harlem2bdrm Apt; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Very Spacious; NER tag: PERSON
# Entity: Manhattan; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Cozy; NER tag: GPE
# Entity: English; NER tag: NORP
# Entity: XLG Studio Apt w/TONS; NER tag: PERSON
# Entity: 1BR; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: DM; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: East Village; NER tag: GPE
# Entity: 1BR; NER tag: CARDINAL
# Entity: Great Flat; NER tag: ORG
# Entity: Historic Brownstone; NER tag: GPE
# Entity: Sunlit Noho Loft; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: Sunny 1 Bdrm; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: APARTMENT - NEW; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: Sunny & Spacious Apt; NER tag: ORG
# Entity: Park Slope; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: Suite; NER tag: PERSON
# Entity: WestVillage; NER tag: ORG
# Entity: Renovated Big Private; NER tag: ORG
# Entity: Cozy; NER tag: GPE
# Entity: NY; NER tag: GPE
# Entity: 3 weeks; NER tag: DATE
# Entity: Brooklyn; NER tag: GPE
# Entity: Nolita; NER tag: GPE
# Entity: 1 bdrm; NER tag: QUANTITY
# Entity: Brownstone - Garden; NER tag: ORG
# Entity: Soho Loft; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: 2bd/2bth Apt W. Village; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Warm & Welcoming Private Room; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Classic; NER tag: PRODUCT
# Entity: Great Studio; NER tag: PERSON
# Entity: Chelsea; NER tag: GPE
# Entity: New York; NER tag: GPE
# Entity: Sunny Brooklyn Artists'; NER tag: PERSON
# Entity: Cozy Room; NER tag: PERSON
# Entity: 1; NER tag: CARDINAL
# Entity: 3; NER tag: CARDINAL
# Entity: Columbus Circle/Central Park/Hells; NER tag: ORG
# Entity: Loft; NER tag: PERSON
# Entity: BK Factory; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: 3; NER tag: CARDINAL
# Entity: Verna's Brownstone Suite; NER tag: ORG
# Entity: Spacious Factory; NER tag: ORG
# Entity: 3; NER tag: CARDINAL
# Entity: groups & 1/Pr'spct PK; NER tag: ORG
# Entity: Unique; NER tag: ORG
# Entity: 3BR; NER tag: CARDINAL
# Entity: Triplex; NER tag: NORP
# Entity: Brooklyn; NER tag: GPE
# Entity: One; NER tag: CARDINAL
# Entity: 1; NER tag: CARDINAL
# Entity: NYC; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: NY Magazine; NER tag: ORG
# Entity: Chic & Stylish; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Loft Brooklyn; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Sunny &; NER tag: ORG
# Entity: W. Harlem; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Sunny Soho Apartment; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Bohemian Paradise; NER tag: LOC
# Entity: BK; NER tag: ORG
# Entity: BROOKLYN; NER tag: GPE
# Entity: Art Deco Chelsea Studio; NER tag: PERSON
# Entity: GREAT; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: Parlor Apt; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: Loft; NER tag: PERSON
# Entity: West Village; NER tag: GPE
# Entity: Williamsburg; NER tag: GPE
# Entity: 1BR; NER tag: CARDINAL
# Entity: New York; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: NY; NER tag: GPE
# Entity: Sunset Park; NER tag: FAC
# Entity: East Village; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: Peaceful Semi-Private; NER tag: PERSON
# Entity: Bright Rm; NER tag: PERSON
# Entity: Village; NER tag: GPE
# Entity: 2BR; NER tag: CARDINAL
# Entity: Columbus Circle Comfort; NER tag: LOC
# Entity: Times Square; NER tag: FAC
# Entity: Greene; NER tag: PERSON
# Entity: Brooklyn; NER tag: GPE
# Entity: W80; NER tag: ORG
# Entity: West Village; NER tag: GPE
# Entity: Lower Manhattan; NER tag: LOC
# Entity: Cozy & Private 1 Bedroom Garden Level Apartment; NER tag: ORG
# Entity: Artsy Harlem Guest Space; NER tag: PERSON
# Entity: Fun & Hip Area; NER tag: ORG
# Entity: Kitchen Apt; NER tag: PERSON
# Entity: New York; NER tag: GPE
# Entity: under 30 days; NER tag: DATE
# Entity: 1Bedroom, Seconds; NER tag: TIME
# Entity: Spacious Loft; NER tag: PERSON
# Entity: East Village; NER tag: GPE
# Entity: Cozy 1BD; NER tag: PERSON
# Entity: Vibrant East Village; NER tag: LOC
# Entity: 1; NER tag: CARDINAL
# Entity: Cozy Studio; NER tag: PERSON
# Entity: Flatbush; NER tag: GPE
# Entity: NYC; NER tag: LOC
# Entity: Studio Apt; NER tag: PERSON
# Entity: Bushwick; NER tag: ORG
# Entity: One; NER tag: CARDINAL
# Entity: Bedroom Apt Near; NER tag: PERSON
# Entity: cozy artist's; NER tag: ORG
# Entity: WV; NER tag: GPE
# Entity: Monthly Rental; NER tag: ORG
# Entity: more than 30 days; NER tag: DATE
# Entity: 6; NER tag: CARDINAL
# Entity: Greenpoint; NER tag: GPE
# Entity: Guesthouse; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: Suite; NER tag: PERSON
# Entity: Cozy; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: Hells Kitchen; NER tag: GPE
# Entity: Historic Townhouse; NER tag: PERSON
# Entity: JFK Jupiter; NER tag: PERSON
# Entity: Suites- Rm; NER tag: PERSON
# Entity: 1; NER tag: MONEY
# Entity: JFK; NER tag: PERSON
# Entity: HK/TIME SQ./THEATER; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: Bedford Stuyvesant Urban Hang Suite; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: 1; NER tag: CARDINAL
# Entity: Bedford Ave; NER tag: ORG
# Entity: Spacious West Village Studio; NER tag: PERSON
# Entity: Luxury 1 Bedroom Upper West; NER tag: PERSON
# Entity: Sunny Apartment; NER tag: PERSON
# Entity: Clinton Hill; NER tag: PERSON
# Entity: Cozy w; NER tag: PERSON
# Entity: Suites- Rm; NER tag: PERSON
# Entity: JFK; NER tag: PERSON
# Entity: SHARED; NER tag: ORG
# Entity: Jupiter Suites; NER tag: PERSON
# Entity: JFK; NER tag: PERSON
# Entity: Cozy East Village; NER tag: PERSON
# Entity: 1br; NER tag: ORDINAL
# Entity: Cozy Twin; NER tag: PERSON
# Entity: the NYC Win; NER tag: ORG
# Entity: Gay/LGBT Friendly; NER tag: ORG
# Entity: NYC; NER tag: LOC
# Entity: 20; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: 1BR; NER tag: CARDINAL
# Entity: 1; NER tag: CARDINAL
# Entity: Fort Greene; NER tag: FAC
# Entity: Chelsea Location; NER tag: ORG
# Entity: Great Chelsea Location; NER tag: ORG
# Entity: Free WiFi; NER tag: PERSON
# Entity: Sunny Private Room; NER tag: ORG
# Entity: Williamsburg; NER tag: GPE
# Entity: Bedroom; NER tag: PERSON
# Entity: Loft Apt; NER tag: PERSON
# Entity: BK Townhouse Home; NER tag: ORG
# Entity: Highland Park; NER tag: FAC
# Entity: Peaceful Studio; NER tag: PERSON
# Entity: Fort Greene; NER tag: GPE
# Entity: Harlem; NER tag: LOC
# Entity: NY Apt; NER tag: ORG
# Entity: 1; NER tag: CARDINAL
# Entity: NewYork; NER tag: ORG
# Entity: 1BR; NER tag: CARDINAL
# Entity: 2BR; NER tag: CARDINAL
# Entity: Sunlight & Secret Garden Apartment; NER tag: ORG
# Entity: Private Bed & Bath; NER tag: ORG
# Entity: Charming Brwnstn Duplex; NER tag: PERSON
# Entity: 5; NER tag: CARDINAL
# Entity: West Village/; NER tag: GPE
# Entity: South Williamsburg; NER tag: GPE
# Entity: Private Huge; NER tag: ORG
# Entity: 2br; NER tag: ORDINAL
# Entity: New York City; NER tag: GPE
# Entity: Grand Central; NER tag: ORG
# Entity: Antique; NER tag: NORP
# Entity: first; NER tag: ORDINAL
# Entity: Brooklyn; NER tag: GPE
# Entity: Garden Rowhouse Duplex-2 bd/3; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: 3; NER tag: CARDINAL
# Entity: Prospect Park; NER tag: FAC
# Entity: Bushwick; NER tag: GPE
# Entity: 2 Bed; NER tag: MONEY
# Entity: NEW YORK; NER tag: GPE
# Entity: Art Dealer's; NER tag: ORG
# Entity: One; NER tag: CARDINAL
# Entity: 1; NER tag: CARDINAL
# Entity: Bed-Stuy; NER tag: ORG
# Entity: McSimon; NER tag: PERSON
# Entity: 10; NER tag: CARDINAL
# Entity: JFK; NER tag: PERSON
# Entity: 2BR+1BA; NER tag: CARDINAL
# Entity: Only 15; NER tag: DATE
# Entity: Midwood; NER tag: GPE
# Entity: Brooklyn; NER tag: GPE
# Entity: CHELSEA; NER tag: ORG
# Entity: GARDEN APT; NER tag: ORG
# Entity: Habitat 101; NER tag: ORG
# Entity: Stuyvesant Heights Townhouse; NER tag: ORG
# Entity: Sunny 1-Bedroom Apartment: Astoria; NER tag: ORG
# Entity: NYC; NER tag: ORG
# Entity: Perfect Temporary Brooklyn Home; NER tag: ORG
# Entity: Chelsea; NER tag: GPE
# Entity: 2bd; NER tag: ORDINAL
# Entity: Soho/Little Italy; NER tag: ORG
# Entity: Summer Park Strolls; NER tag: ORG
# Entity: Sunny Spacious; NER tag: PERSON
# Entity: 2; NER tag: CARDINAL
# Entity: Cozy; NER tag: GPE
# Entity: EV; NER tag: ORG
# Entity: Hippest East Village; NER tag: ORG
# Entity: Terrific Price; NER tag: ORG
# Entity: Park Slope; NER tag: ORG
# Entity: 3+; NER tag: DATE
# Entity: One; NER tag: CARDINAL
# Entity: Astoria; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: CLEAN HOME AWAY FROM HOME; NER tag: ORG
# Entity: Beautiful Studio; NER tag: PERSON
# Entity: Harlem; NER tag: LOC
# Entity: Universe; NER tag: ORG
# Entity: 2; NER tag: CARDINAL
# Entity: 2; NER tag: CARDINAL
# Entity: East Village; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: 1BR Near Columbia; NER tag: PERCENT
# Entity: Entire Modern Studio Apartment/Prime Location; NER tag: ORG
# Entity: Loft; NER tag: PERSON
# Entity: Williamsburg; NER tag: GPE
# Entity: Cozy Room; NER tag: PERSON
# Entity: South Williamsburg; NER tag: GPE
# Entity: NYC; NER tag: ORG
# Entity: 3; NER tag: CARDINAL
# Entity: Manhattan; NER tag: GPE
# Entity: New York City; NER tag: GPE
# Entity: Park Carriage; NER tag: ORG
# Entity: Loft; NER tag: PERSON
# Entity: 1BDR; NER tag: CARDINAL
# Entity: EAST VILLAGE; NER tag: GPE
# Entity: NEW YORK; NER tag: GPE
# Entity: East Village; NER tag: GPE
# Entity: Entire Floor of Brooklyn Brownstone; NER tag: ORG
# Entity: Harlem; NER tag: LOC
# Entity: New Yorkers; NER tag: NORP
# Entity: Sunny Greenpoint Flat; NER tag: ORG
# Entity: Astoria; NER tag: GPE
# Entity: Manhattan; NER tag: GPE
# Entity: 1; NER tag: CARDINAL
# Entity: APT SoHo /; NER tag: ORG
# Entity: Modern Design; NER tag: ORG
# Entity: West Village; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: 850; NER tag: CARDINAL
# Entity: Hudson; NER tag: LOC
# Entity: Flatbush; NER tag: ORG
# Entity: Brooklyn; NER tag: GPE
# Entity: Queens; NER tag: GPE
# Entity: QUEENS; NER tag: ORG
# Entity: Beautiful Brownstone; NER tag: PERSON
# Entity: West Harlem; NER tag: GPE
# Entity: 2; NER tag: CARDINAL
# Entity: NY; NER tag: GPE
# Entity: Williamsburg; NER tag: GPE
# Entity: Williamsburg; NER tag: GPE
# Entity: Designer Home; NER tag: ORG
# Entity: Manhattan; NER tag: GPE
# Entity: Alexa; NER tag: ORG
# Entity: Smart Home; NER tag: ORG
# Entity: Astoria; NER tag: GPE
# Entity: West Village; NER tag: GPE
# Entity: SUNNY STUDIO MIDTOWN; NER tag: ORG
# Entity: 1Br; NER tag: CARDINAL
# Entity: Jupiter Suites; NER tag: PERSON
# Entity: #4; NER tag: MONEY
# Entity: Cozy; NER tag: GPE
# Entity: QUIET Dream Home; NER tag: ORG
# Entity: Chelsea; NER tag: ORG
# Entity: 2BR; NER tag: CARDINAL
# Entity: Bushwick; NER tag: ORG
# Entity: CENTRAL; NER tag: ORG
# Entity: Sunny Studio Loft @ Habitat; NER tag: PERSON
# Entity: East Village; NER tag: GPE
# Entity: Park Slope Jr 1; NER tag: PERSON
# Entity: Astoria; NER tag: GPE
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 9
#       3     for i in words.ents:
#       4         print("Entity: " + i.text + "; NER tag: " + i.label_)
# ----> 9 ab.name.apply(airbnb)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[74], line 2, in airbnb(r)
#       1 def airbnb(r):
# ----> 2     words = nlp(r)
#       3     for i in words.ents:
#       4         print("Entity: " + i.text + "; NER tag: " + i.label_)
#
# File /opt/anaconda3/lib/python3.13/site-packages/spacy/language.py:1041, in Language.__call__(self, text, disable, component_cfg)
#    1020 def __call__(
#    1021     self,
#    1022     text: Union[str, Doc],
#    (...)   1025     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#    1026 ) -> Doc:
#    1027     """Apply the pipeline to some text. The text can span multiple sentences,
#    1028     and can contain arbitrary whitespace. Alignment into the original string
#    1029     is preserved.
#    (...)   1039     DOCS: https://spacy.io/api/language#call
#    1040     """
# -> 1041     doc = self._ensure_doc(text)
#    1042     if component_cfg is None:
#    1043         component_cfg = {}
#
# File /opt/anaconda3/lib/python3.13/site-packages/spacy/language.py:1135, in Language._ensure_doc(self, doc_like)
#    1133 if isinstance(doc_like, bytes):
#    1134     return Doc(self.vocab).from_bytes(doc_like)
# -> 1135 raise ValueError(Errors.E1041.format(type=type(doc_like)))
#
# ValueError: [E1041] Expected a string, Doc, or bytes as input, but got: <class 'float'>

# %% [markdown]
# ## Sentiment analysis

# %% [markdown]
# ### Using the default scorer on a few example phrases

# %%
## initialize a scorer
sent_obj = SentimentIntensityAnalyzer()
print(type(sent_obj))
## score one listing
practice_listing = "NICE AND COZY LITTLE APT AVAILABLE"
sentiment_example = sent_obj.polarity_scores(practice_listing)
sentiment_example
# Out:
# <class 'vaderSentiment.vaderSentiment.SentimentIntensityAnalyzer'>
# {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.4215}

# %%
## adding phrase with word terrible and score
practice_listing_2 = "NICE AND COZY LITTLE APT AVAILABLE. REALLY TERRIBLE VIEW."
sentiment_example_2 = sent_obj.polarity_scores(practice_listing_2)

# %%
## adding phrase about rats; bad but might not be in scoring dictionary
practice_listing_3 = "NICE AND COZY LITTLE APT AVAILABLE. HAS RATS THOUGH."
sentiment_example_3 = sent_obj.polarity_scores(practice_listing_3)

# %%
## summarize all 3
print("String: " + practice_listing + " scored as:\n" + str(sentiment_example))
print("String: " + practice_listing_2 + " scored as:\n" + str(sentiment_example_2))
print("String: " + practice_listing_3 + " scored as:\n" + str(sentiment_example_3))
# Out:
# String: NICE AND COZY LITTLE APT AVAILABLE scored as:
# {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.4215}
# String: NICE AND COZY LITTLE APT AVAILABLE. REALLY TERRIBLE VIEW. scored as:
# {'neg': 0.257, 'neu': 0.531, 'pos': 0.212, 'compound': -0.1513}
# String: NICE AND COZY LITTLE APT AVAILABLE. HAS RATS THOUGH. scored as:
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4215}

# %% [markdown]
# ### Updating the dictionary with manually-added words

# %%
print(type(sent_obj.lexicon))
# Out:
# <class 'dict'>

# %%
## lexicon is a dictionary where the key
## is the word
## the value is the score (negative = negative)
## here, i'm benchmarking the negativity of the
## rodents to the negativity of the word aversion
sent_obj.lexicon['aversion']
# Out:
# -1.9

# %%
## create a dictionary with 
## negative scores for pests
pest_words = {
    'rat': -1.9,
    'rats': -1.9,
    'mice': -1.9,
    'mouse': -1.9,
    'roach': -1.9,
    'cockroach': -1.9
}


## initiate new sentiment object
## so that we don't alter old one
## use.update to add new words
new_si = SentimentIntensityAnalyzer()
new_si.lexicon.update(pest_words)

## try re-scoring the third example
## see negative
print("After lexicon update: " + practice_listing_3 + " scored as:\n" + \
      str(new_si.polarity_scores(practice_listing_3)))
# Out:
# After lexicon update: NICE AND COZY LITTLE APT AVAILABLE. HAS RATS THOUGH. scored as:
# {'neg': 0.228, 'neu': 0.551, 'pos': 0.22, 'compound': -0.0258}
